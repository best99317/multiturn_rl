# %%
import pandas as pd 
df = pd.read_csv('llama3-2-1b-instruct/conversation_pairs_generated.csv')
print(df['id'])
# Out:
# 0         391
# 1         415
# 2         418
# 3         419
# 4         426
#         ...
# 8626    19911
# 8627    19913
# 8628    19917
# 8629    19918
# 8630    19920
# Name: id, Length: 8631, dtype: int64
